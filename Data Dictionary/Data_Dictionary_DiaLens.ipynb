# %%
import pandas as pd

# %%
# Menyiapkan Data Dictionary untuk Diabetes Health Indicators
diabetes_data = [
    ["label", "[Target] Status klasifikasi penyakit diabetes pasien.", "Integer", "0 = Tidak Diabetes, 1 = Prediabetes / Diabetes"],
    ["Age_BMI_Risk", "[Fitur Baru] Tingkat risiko gabungan antara faktor Usia dan Indeks Massa Tubuh (Age x BMI).", "Float", "Angka numerik positif (16.0 - 507.0)"],
    ["Unhealthy_Score", "[Fitur Baru] Skor akumulasi gaya hidup tidak sehat (Smoker + HvyAlcoholConsump + (1 - PhysActivity)).", "Float", "Skala 0.0 - 3.0"],
    ["HighBP", "Riwayat tekanan darah tinggi.", "Float (Biner)", "0 = Tidak, 1 = Ya"],
    ["HighChol", "Riwayat kolesterol tinggi.", "Float (Biner)", "0 = Tidak, 1 = Ya"],
    ["CholCheck", "Melakukan pemeriksaan kolesterol dalam 5 tahun terakhir.", "Float (Biner)", "0 = Tidak, 1 = Ya"],
    ["BMI", "Nilai Body Mass Index (Indeks Massa Tubuh).", "Float", "Angka numerik (12.0 - 100.0)"],
    ["Smoker", "Pernah merokok minimal 100 batang seumur hidup.", "Float (Biner)", "0 = Tidak, 1 = Ya"],
    ["Stroke", "Memiliki riwayat penyakit stroke.", "Float (Biner)", "0 = Tidak, 1 = Ya"],
    ["HeartDiseaseorAttack", "Memiliki riwayat penyakit jantung koroner atau serangan jantung.", "Float (Biner)", "0 = Tidak, 1 = Ya"],
    ["PhysActivity", "Melakukan aktivitas fisik ringan/olahraga dalam 30 hari terakhir.", "Float (Biner)", "0 = Tidak, 1 = Ya"],
    ["Fruits", "Mengonsumsi buah 1 kali atau lebih per hari.", "Float (Biner)", "0 = Tidak, 1 = Ya"],
    ["Veggies", "Mengonsumsi sayur 1 kali atau lebih per hari.", "Float (Biner)", "0 = Tidak, 1 = Ya"],
    ["HvyAlcoholConsump", "Konsumsi alkohol berat per minggu (Pria > 14, Wanita > 7).", "Float (Biner)", "0 = Tidak, 1 = Ya"],
    ["AnyHealthcare", "Memiliki asuransi / jaminan perawatan kesehatan.", "Float (Biner)", "0 = Tidak, 1 = Ya"],
    ["NoDocbcCost", "Gagal ke dokter dalam 12 bulan terakhir akibat kendala biaya.", "Float (Biner)", "0 = Tidak, 1 = Ya"],
    ["GenHlth", "Evaluasi kondisi kesehatan umum secara mandiri.", "Float", "Skala 1 - 5 (1 = Sangat Baik, 5 = Buruk)"],
    ["MentHlth", "Jumlah hari dengan kondisi kesehatan mental buruk dalam sebulan terakhir.", "Float", "0.0 - 30.0 hari"],
    ["PhysHlth", "Jumlah hari sakit secara fisik/cedera dalam sebulan terakhir.", "Float", "0.0 - 30.0 hari"],
    ["DiffWalk", "Kesulitan serius dalam berjalan kaki atau menaiki tangga.", "Float (Biner)", "0 = Tidak, 1 = Ya"],
    ["Sex", "Jenis kelamin pasien.", "Float (Biner)", "0 = Wanita, 1 = Pria"],
    ["Age", "Kategori rentang usia pasien (dibagi menjadi 13 kategori).", "Float", "Skala 1 - 13 (1 = 18-24 thn, 13 = >= 80 thn)"],
    ["Education", "Tingkat pendidikan tertinggi yang diselesaikan.", "Float", "Skala 1 - 6 (1 = TK/Tidak Sekolah, 6 = Lulus Kuliah)"],
    ["Income", "Kategori level pendapatan keluarga per tahun.", "Float", "Skala 1 - 8 (1 = < $10.000, 8 = >= $75.000)"]
]
df_diabetes = pd.DataFrame(diabetes_data, columns=["Nama Elemen Data", "Deskripsi", "Tipe Data", "Nilai yang Diizinkan / Validasi"])

# %%
# Mengekspor menjadi satu file Excel
file_name = "Data_Dictionary_DiaLens.xlsx"
with pd.ExcelWriter(file_name) as writer:
    df_diabetes.to_excel(writer, sheet_name="Diabetes_Health", index=False)

print(f"Data Dictionary berhasil dibuat dan disimpan sebagai: {file_name}")
# Out:
# Data Dictionary berhasil dibuat dan disimpan sebagai: Data_Dictionary_DiaLens.xlsx
